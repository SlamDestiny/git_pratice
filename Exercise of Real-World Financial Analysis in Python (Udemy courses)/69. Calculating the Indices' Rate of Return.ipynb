# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ['^GSPC','^IXIC', '^GDAXI']

ind_data = pd.DataFrame()

for t in tickers:
	ind_data[t] = wb.DataReader(t, data_source= 'yahoo', start='1997-1-1')['Adj Close']

# %%
ind_data.head()
# Out:
#                  ^GSPC        ^IXIC       ^GDAXI
# Date
# 1997-01-02  737.010010  1280.699951  2820.810059
# 1997-01-03  748.030029  1310.680054  2863.260010
# 1997-01-06  747.650024  1316.400024  2890.199951
# 1997-01-07  753.229980  1327.729980  2876.340088
# 1997-01-08  748.409973  1320.349976  2904.080078

# %%
ind_data.tail()
# Out:
#                   ^GSPC         ^IXIC        ^GDAXI
# Date
# 2020-07-13  3155.219971  10390.839844  12799.969727
# 2020-07-14  3197.520020  10488.580078  12697.360352
# 2020-07-15  3226.560059  10550.490234  12930.980469
# 2020-07-16  3215.570068  10473.830078  12874.969727
# 2020-07-17  3224.729980  10503.190430  12919.610352

# %%
(ind_data / ind_data.iloc[0]*100).plot(figsize=(15,6));
plt.show()

# %%
ind_returns=(ind_data / ind_data.shift(1))-1
ind_returns.tail()
# Out:
#                ^GSPC     ^IXIC    ^GDAXI
# Date
# 2020-07-13 -0.009363 -0.021342  0.013160
# 2020-07-14  0.013406  0.009406 -0.008016
# 2020-07-15  0.009082  0.005903  0.018399
# 2020-07-16 -0.003406 -0.007266 -0.004332
# 2020-07-17  0.002849  0.002803  0.003467

# %%
annual_ind_returns = ind_returns.mean()*250
annual_ind_returns
# Out:
# ^GSPC     0.081819
# ^IXIC     0.120691
# ^GDAXI    0.077678
# dtype: float64

# %%
tickers = ['PG', '^GSPC', '^DJI']

data_2 = pd.DataFrame()

for t in tickers:
	data_2[t]= wb.DataReader(t, data_source= 'yahoo', start = '2007-1-1')['Adj Close']

# %%
data_2.tail()
# Out:
#                     PG        ^GSPC          ^DJI
# Date
# 2020-07-13  124.050003  3155.219971  26085.800781
# 2020-07-14  125.089996  3197.520020  26642.589844
# 2020-07-15  124.500000  3226.560059  26870.099609
# 2020-07-16  124.760002  3215.570068  26734.710938
# 2020-07-17  125.629997  3224.729980  26671.949219

# %%
(data_2/data_2.iloc[0]*100).plot(figsize=(15,6));
plt.show()
